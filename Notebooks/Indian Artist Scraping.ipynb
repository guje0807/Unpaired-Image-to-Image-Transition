# %%
import requests as req
from bs4 import BeautifulSoup
import wget as w

# %%
r = req.get("https://pixabay.com/images/search/india%20tourism/")
url_data = r.text
soup = BeautifulSoup(url_data, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <title>
#    Just a moment...
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex,nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"/>
#  </head>
#  <body class="no-js">
#   <div class="main-wrapper" role="main">
#    <div class="main-content">
#     <h1 class="zone-name-title h1">
#      <img alt="Icon for pixabay.com" class="heading-favicon" onerror="this.onerror=null;this.parentNode.removeChild(this)" src="/favicon.ico"/>
#      pixabay.com
#     </h1>
#     <h2 class="h2" id="challenge-running">
#      Checking if the site connection is secure
#     </h2>
#     <noscript>
#      <div id="challenge-error-title">
#       <div class="h2">
#        <span class="icon-wrapper">
#         <div class="heading-icon warning-icon">
#         </div>
#        </span>
#        <span id="challenge-error-text">
#         Enable JavaScript and cookies to continue
#        </span>
#       </div>
#      </div>
#     </noscript>
#     <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/captcha/nojs/transparent.gif?ray=793dcd610a903ff1')">
#     </div>
#     <div class="core-msg spacer" id="challenge-body-text">
#      pixabay.com needs to review the security of your connection before proceeding.
#     </div>
#     <form action="/images/search/india%20tourism/?__cf_chl_f_tk=1xFJJ_1io60spGztfCebS5dxXdfIDyKUvVm3Dry.WuA-1675454945-0-gaNycGzNB2U" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
#      <input name="md" type="hidden" value="M9445cTYNcSvo5uwV9HTYQsIRUBA8Hxd3lwW33bZkKI-1675454945-0-AeCaA1KZbaFEnnbVIyhvBnh1p5HBGPdEysbGKluQhQkEs4s4heizbfv08_FvFIEDqrV16uZah2YeOTmRVPebu5bUrTEsXsEwC4zmADCopikTClXKmUTgBzphcO1NLiYBX5Nm0oMPnuG1_D_ZdOjKNukhcTELvyuwEsW-3qAFxVohbYY7Z9RpDNQd5AlcmrnIalCSoJRYyN5hZxW7UPpQqzh6GLELdzJkIyOFSW4kP2yz25Lc263KmF2loJcsqXCZ2F6r7D5pRYeMmCX64i7pnRBF3EB1Vqr_99GPV54_HljC9KV1FcFtZqyYUV0rMnjRZD1SIfidVl18aWbvrxUV5V7MHufuXr6Vc4JRXOgKlohEie_gNHWNT1F1um83fQ2t3sv7XncLCiEGYSFASEDwE7fb4E2L9393BO1V_t-wOVD27beRt1f0HjKLJi7jyUcbfdxXstU5o6cjjwzdxfSFZrEVUBkqIj9hiR5XV8mVUiYyKrEPlnHJVl9T0mQ-0eaQZjwmb9pXoX2-c_qm9c4_1GU"/>
#      <input name="r" type="hidden" value="2NUQGw8GHYewVy5XyqiAalui39Jb0wG8zaIpE_SBx1s-1675454945-0-..."/>
#     </form>
#    </div>
#   </div>
#   <script>
#    (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cZone: 'pixabay.com',
#             cType: 'interactive',
#             cNounce: '62492',
#             cRay: '793dcd610a903ff1',
#             cHash: '892afe2baeb47a4',
#             cUPMDTk: "\/images\/search\/india%20tourism\/?__cf_chl_tk=1xFJJ_1io60spGztfCebS5dxXdfIDyKUvVm3Dry.WuA-1675454945-0-gaNycGzNB2U",
#             cFPWv: 'b',
#             cTTimeMs: '1000',
#             cMTimeMs: '0',
#             cTplV: 4,
#             cTplB: 'cf',
#             cRq: {
#                 ru: 'aHR0cHM6Ly9waXhhYmF5LmNvbS9pbWFnZXMvc2VhcmNoL2luZGlhJTIwdG91cmlzbS8=',
#                 ra: 'cHl0aG9uLXJlcXVlc3RzLzIuMjguMQ==',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY3NTQ1NDk0NS40NDEwMDA=',
#                 m: 'kPwARNWVs8IRONmbFLixAQQtokGmb/HLrlFFfZQQB10=',
#                 i1: 'YwpKabU7mVNM1S+/95B7XA==',
#                 i2: '1agiLb43AXxvGAnRQ5safA==',
#                 zh: 'rn4uVVI55DugAe2oDwA8RdEOOxslcW1vAsJM/MDyRnY=',
#                 uh: 'SLdVolODg++SO356HusO5I/hbfOpiiOxQXj62i/MUkA=',
#                 hh: '9lZ7QacdPX/XIUWg44BYGVRIsqwHE/7A97JjwS5aDEM=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/captcha/js/transparent.gif?ray=793dcd610a903ff1');
#         trkjs.setAttribute('alt', '');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/b/orchestrate/captcha/v1?ray=793dcd610a903ff1';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, location.href.length - window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/images\/search\/india%20tourism\/?__cf_chl_rt_tk=1xFJJ_1io60spGztfCebS5dxXdfIDyKUvVm3Dry.WuA-1675454945-0-gaNycGzNB2U" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#   </script>
#   <div class="footer" role="contentinfo">
#    <div class="footer-inner">
#     <div class="clearfix diagnostic-wrapper">
#      <div class="ray-id">
#       Ray ID:
#       <code>
#        793dcd610a903ff1
#       </code>
#      </div>
#     </div>
#     <div class="text-center" id="footer-text">
#      Performance &amp; security by
#      <a href="https://www.cloudflare.com?utm_source=challenge&amp;utm_campaign=l" rel="noopener noreferrer" target="_blank">
#       Cloudflare
#      </a>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
from pinterest import PinterestImageScraper
p_scraper = PinterestImageScraper()
is_downloaded = p_scraper.make_ready("messi")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from pinterest import PinterestImageScraper
#       2 p_scraper = PinterestImageScraper()
#       3 is_downloaded = p_scraper.make_ready("messi")
#
# ModuleNotFoundError: No module named 'pinterest'
