# %%
import requests 
from bs4 import BeautifulSoup 
import csv
import pandas as pd
import urllib.request

# %%
def getdata(url): 
    r = requests.get(url) 
    return r.text

# %%
htmldata = getdata("https://www.wikiart.org/en/raja-ravi-varma")

# %%
#htmldata

# %%
soup = BeautifulSoup(htmldata, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- Google Tag Manager -->
# <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#             'gtm.start':
#                 new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-P53MQNQ');</script>
# <!-- End Google Tag Manager -->
# <title>Raja Ravi Varma - 51 artworks - painting</title>
# <link href="https://www.wikiart.org/en/raja-ravi-varma" rel="canonical"/>
# <link href="//uploads.wikiart.org/" rel="dns-prefetch"/>
# <link href="//uploads.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads0.wikiart.org" rel="dns-prefetch"/>
# ...

# %%
#for item in soup.find_all('img'):
        #print(item['src'])

# %%
f = open('D:\\Lambton\\Sem 3\\Capstone project\\url_list.csv', 'w')
writer = csv.writer(f)
for item in soup.find_all('img'):
    if "Content" in item['src'] or "temp" in item['src']:
        pass
    else:
        writer.writerow([item['src']])
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 f = open('D:\\Lambton\\Sem 3\\Capstone project\\url_list.csv', 'w')
#       2 writer = csv.writer(f)
#       3 for item in soup.find_all('img'):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Lambton\\Sem 3\\Capstone project\\url_list.csv'

# %%
filename="D:\\Lambton\\Sem 3\\Capstone project\\url_list.csv"
filepath="D:\\Lambton\\Sem 3\\Capstone project\\Images\\"

# %%
urls = pd.read_csv(filename,header=None,names=["URL"])

# %%
urls.values[0]
# Out:
# array(['https://uploads1.wikiart.org/images/raja-ravi-varma/arjuna-and-subhadra-1890.jpg!PinterestSmall.jpg'],
#       dtype=object)

# %%
def url_to_jpg(i,url,file_path):
    filename = 'image-{}.jpg'.format(i)
    full_path = "{}{}".format(file_path,filename)
    urllib.request.urlretrieve(url,full_path)
    
    print("{} saved".format(filename))
    return None

# %%
for i,url in enumerate(urls.values):
    url_to_jpg(i,url[0],filepath)
# Out:
# image-0.jpg saved
# image-1.jpg saved
# image-2.jpg saved
# image-3.jpg saved
# image-4.jpg saved
# image-5.jpg saved
# image-6.jpg saved
# image-7.jpg saved
# image-8.jpg saved
# image-9.jpg saved
# image-10.jpg saved
# image-11.jpg saved
# image-12.jpg saved
# image-13.jpg saved
# image-14.jpg saved
# image-15.jpg saved
# image-16.jpg saved
# image-17.jpg saved
# image-18.jpg saved

# %%
htmldata = getdata("https://www.wikiart.org/en/m-f-husain/all-works#!#filterName:all-paintings-alphabetically,resultType:masonry")

# %%
soup = BeautifulSoup(htmldata, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- Google Tag Manager -->
# <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#             'gtm.start':
#                 new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-P53MQNQ');</script>
# <!-- End Google Tag Manager -->
# <title>M.F. Husain - 79 artworks - painting</title>
# <link href="https://www.wikiart.org/en/m-f-husain/all-works" rel="canonical"/>
# <link href="//uploads.wikiart.org/" rel="dns-prefetch"/>
# <link href="//uploads.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads0.wikiart.org" rel="dns-prefetch"/>
# ...

# %%
# for image in soup.find_all('div', attrs={"class":"view-all-works"}):
        print(image["items"])

# %%
for image in soup.find_all('div', attrs={"class":"view-all-works"}):
                print(image)
# Out:
# <div class="view-all-works" ng-cloak="" ng-controller="MasonryCtrl" ng-init="options = {'masonryId' : 'view-all-works', 'initialPortion' : {'items' :  { &quot;_t&quot; : &quot;System.Linq.Enumerable+WhereSelectArrayIterator`2[[Wikipaintings.Mongo.Model.MongoPainting, Wikipaintings.Mongo],[Wikipaintings.Web.Models.Partials.PaintingForGalleryNew, Wikipaintings.Web]]&quot;, &quot;_v&quot; : [{ &quot;_id&quot; : &quot;57728641edc2cb3880039a8e&quot;, &quot;title&quot; : &quot;Blue Nursery with Bambi&quot;, &quot;year&quot; : &quot;1946&quot;, &quot;width&quot; : 570, &quot;height&quot; : 376, &quot;artistName&quot; : &quot;M.F. Husain&quot;, &quot;image&quot; : &quot;https://uploads0.wikiart.org/images/m-f-husain/blue-nursery-with-bambi-1946.jpg&quot;, &quot;map&quot; : &quot;0*23**67*&quot;, &quot;paintingUrl&quot; : &quot;/en/m-f-husain/blue-nursery-with-bambi-1946&quot;, &quot;artistUrl&quot; : &quot;/en/m-f-husain&quot;, &quot;albums&quot; : null, &quot;flags&quot; : 2, &quot;images&q
# ...

# %%
a = getdata('https://www.wikiart.org/en/raja-ravi-varma/all-works/text-list')

# %%
soup = BeautifulSoup(a, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <!-- Google Tag Manager -->\n  <script>\n   (function (w, d, s, l, i) {\n        w[l] = w[l] || []; w[l].push({\n            \'gtm.start\':\n                new Date().getTime(), event: \'gtm.js\'\n        }); var f = d.getElementsByTagName(s)[0],\n            j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\'; j.async = true; j.src =\n                \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl; f.parentNode.insertBefore(j, f);\n        })(window, document, \'script\', \'dataLayer\', \'GTM-P53MQNQ\');\n  </script>\n  <!-- End Google Tag Manager -->\n  <title>\n   Raja Ravi Varma - 51 artworks - painting\n  </title>\n  <link href="https://www.wikiart.org/en/raja-ravi-varma/all-works/text-list" rel="canonical"/>\n  <link href="//uploads.wikiart.org/" rel="dns-prefetch"/>\n  <link href="//uploads.wikiart.org" rel="dns-prefetch"/>\n  <link href="//uploads0.wikiart.org" rel="dns-prefetch"/>\n  <link href="//uploads1.wikia
# ...

# %%
raja_ravi_varma_list = []
table = soup.find_all('a')
for i in table:
    if i.has_attr('href'):
        if '/en/raja-ravi-varma/' in str(i['href']):
            #raja_ravi_varma_list.append("https://www.wikiart.org/" + str(i['href']))
            print(i['href'])
            raja_ravi_varma_list.append(str(i['href']))
# Out:
# /en/raja-ravi-varma/lady-with-swarbat-1874
# /en/raja-ravi-varma/arjuna-and-subhadra-1890
# /en/raja-ravi-varma/santhanu-and-matsyagandhi-1890
# /en/raja-ravi-varma/radha-and-madhav-1890
# /en/raja-ravi-varma/there-comes-papa-1893
# /en/raja-ravi-varma/gypsies-1893
# /en/raja-ravi-varma/jatayu-vadham-1895
# /en/raja-ravi-varma/painting-of-the-goddess-saraswati-1896
# /en/raja-ravi-varma/shakuntala-1898
# /en/raja-ravi-varma/hamsa-damayanti-1899
# /en/raja-ravi-varma/mohini-and-rugmangada-to-kill-his-own-son-raja-ravi-varma-1899
# /en/raja-ravi-varma/menaka-the-nymph-tempting-the-yogi-1900
# /en/raja-ravi-varma/the-milkmaid-1904
# /en/raja-ravi-varma/victory-of-meghanada-1905
# /en/raja-ravi-varma/lakshmi-the-goddess-of-wealth-1906
# /en/raja-ravi-varma/dattatreya-1910
# /en/raja-ravi-varma/ganga-avataran-or-descent-of-ganga-1910
# /en/raja-ravi-varma/maharaja-fateh-singh
# /en/raja-ravi-varma/kadambari-0
# /en/raja-ravi-varma/kadambari
# /en/raja-ravi-varma/fresh-from-bath
# ...

# %%
raja_ravi_varma_list
# Out:
# ['/en/raja-ravi-varma/lady-with-swarbat-1874',
#  '/en/raja-ravi-varma/arjuna-and-subhadra-1890',
#  '/en/raja-ravi-varma/santhanu-and-matsyagandhi-1890',
#  '/en/raja-ravi-varma/radha-and-madhav-1890',
#  '/en/raja-ravi-varma/there-comes-papa-1893',
#  '/en/raja-ravi-varma/gypsies-1893',
#  '/en/raja-ravi-varma/jatayu-vadham-1895',
#  '/en/raja-ravi-varma/painting-of-the-goddess-saraswati-1896',
#  '/en/raja-ravi-varma/shakuntala-1898',
#  '/en/raja-ravi-varma/hamsa-damayanti-1899',
#  '/en/raja-ravi-varma/mohini-and-rugmangada-to-kill-his-own-son-raja-ravi-varma-1899',
#  '/en/raja-ravi-varma/menaka-the-nymph-tempting-the-yogi-1900',
#  '/en/raja-ravi-varma/the-milkmaid-1904',
#  '/en/raja-ravi-varma/victory-of-meghanada-1905',
#  '/en/raja-ravi-varma/lakshmi-the-goddess-of-wealth-1906',
#  '/en/raja-ravi-varma/dattatreya-1910',
#  '/en/raja-ravi-varma/ganga-avataran-or-descent-of-ganga-1910',
#  '/en/raja-ravi-varma/maharaja-fateh-singh',
#  '/en/raja-ravi-varma/kadambari-0',
# ...

# %%
for i in raja_ravi_varma_list:
    print(i)
    file_n = i
    print(file_n)
    file_p = 'D:\\Lambton\\Sem 3\\Capstone project\\Images\\'
    print(file_p)
    full_p = "{}{}".format(file_p,file_n)
    print(full_p)
    agent = {"User-Agent":'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}
    url = "https://www.wikiart.org/" + i 
    print(url)
    #a = urllib.request.urlretrieve(url, outfile:full_p)
    #img_data = requests.get(url).content
    #with open('i', 'wb') as handler:
    #    handler.write(img_data)
    #break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for i in raja_ravi_varma_list:
#       2     print(i)
#       3     file_n = i
#
# NameError: name 'raja_ravi_varma_list' is not defined

# %%
# Out:
# ('C:\\Users\\noahr\\AppData\\Local\\Temp\\tmpqvsfgka9',
#  <http.client.HTTPMessage at 0x2305d445670>)
